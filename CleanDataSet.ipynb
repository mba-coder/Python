# %%
import pandas as pd

# %%
df=pd.read_csv("superstore_dataset2011-2015 2.csv")
df.head()
# Out:
#    Unnamed: 0  Row ID        Order ID Order Date Ship Date       Ship Mode  \
# 0           7   34662  CA-2011-115161   01/02/11  03/02/11     First Class
# 1          27   37844  CA-2011-113880   01/03/11  05/03/11  Standard Class
# 2          32   31454  CA-2011-104269   01/03/11  06/03/11    Second Class
# 3          34   39607  CA-2011-168312   01/03/11  07/03/11  Standard Class
# 4          36   39245  CA-2011-131009   01/03/11  05/03/11  Standard Class
#
#   Customer ID     Customer Name      Segment           City  ...  \
# 0    LC-17050      Liz Carlisle     Consumer  Mission Viejo  ...
# 1    VF-21715    Vicky Freymann  Home Office       Elmhurst  ...
# 2    DB-13060       Dave Brooks     Consumer        Seattle  ...
# 3    GW-14605  Giulietta Weimer     Consumer        Houston  ...
# 4    SC-20380  Shahid Collister     Consumer        El Paso  ...
#
#         Product ID   Category  Sub-Category  \
# 0  FUR-BO-10003966  Furniture     Bookcases
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State',
#        'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.to_csv("cleaned_superstore_dataset2011-2015.csv", index=False)
print("Dataset cleaned and saved as 'cleaned_superstore_dataset2011-2015.csv'")
# Out:
# Dataset cleaned and saved as 'cleaned_superstore_dataset2011-2015.csv'
